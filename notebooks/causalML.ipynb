# %%
# !pip install -q econml causalml
# !pip install -q scikit-learn
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# causalml 0.15.5 requires shap, which is not installed.
# econml 0.16.0 requires shap<0.49.0,>=0.38.1, which is not installed.
# econml 0.16.0 requires scikit-learn<1.7,>=1.0, but you have scikit-learn 1.7.2 which is incompatible.
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Imports: 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# Scikit-learn
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# EconML (Microsoft)
from econml.dml import CausalForestDML, LinearDML
from econml.grf import CausalForest

# CausalML (Uber)
from causalml.inference.meta import BaseSRegressor, BaseTRegressor, BaseXRegressor
from causalml.metrics import plot_gain, plot_qini
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 11
#       8 warnings.filterwarnings('ignore')
#      10 # Scikit-learn
# ---> 11 from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
#      12 from sklearn.model_selection import train_test_split
#      13 from sklearn.preprocessing import StandardScaler
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# XGBoost for meta-learners
try:
    from xgboost import XGBRegressor
    print("✓ XGBoost available")
except:
    print("⚠️ XGBoost not available, using GradientBoostingRegressor")
    XGBRegressor = GradientBoostingRegressor

# Visualization
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 11

print("="*70)
print("CAUSAL MACHINE LEARNING - HETEROGENEOUS EFFECTS")
print("="*70)
print(f"Date: {datetime.now().strftime('%Y-%m-%d %H:%M')}")

# %%
# File Paths and Directories:
import os
from pathlib import Path

# Get project root (assuming notebook is in notebooks/)
PROJECT_ROOT = Path(__file__).parent.parent if '__file__' in globals() else Path('.').parent.absolute()

# Input paths
FEATURES_PATH = PROJECT_ROOT / "data" / "processed"
PROCESSED_PATH = PROJECT_ROOT / "data" / "processed"

# Output paths
CAUSAL_ML_OUTPUT = PROJECT_ROOT / "outputs" / "causal_ml"
FIGURES_PATH = PROJECT_ROOT / "outputs" / "figures" / "causal"

# Create directories
for path in [CAUSAL_ML_OUTPUT, FIGURES_PATH]:
    path.mkdir(parents=True, exist_ok=True)
    
print(f"Project root: {PROJECT_ROOT}")
print(f"Data path: {FEATURES_PATH}")
print(f"Output path: {CAUSAL_ML_OUTPUT}")

# %% [markdown]
# **Load Data**

# %%
full_df = pd.read_csv(FEATURES_PATH + '')
